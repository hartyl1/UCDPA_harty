# %% [markdown]
# <a href="https://colab.research.google.com/github/hartyl1/UCDPA_harty/blob/main/Copy_of_Copy_of_Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Data-For this project i am using a dataset called nct describing the pass and fail of the NCT test in Ireland from 2006 to 2020.  The data has been sourced from the Road Safety Authority

# %% [markdown]
# I created a dataframe from a csv file  The csv file called nct is saved to my local drive and i imported here and named it nct.

# %%
nct = pd.read_csv('nct.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e6e4e54a317e> in <module>
# ----> 1 nct = pd.read_csv('nct.csv')
#
# NameError: name 'pd' is not defined

# %%
nct
# Out:
#                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 5 columns]

# %% [markdown]
# Retrieve data using API's

# %%
import requests

# %%
rte=requests.get('http://rte.ie')

# %%
rte.history
# Out:
# [<Response [301]>, <Response [301]>]

# %%
rte.url
# Out:
# 'https://www.rte.ie/'

# %%
rte.status_code
# Out:
# 200

# %%
rte.text
# Out:
# '\n<!DOCTYPE html>\n<html class="no-js" lang="en">\n<head>\n\n<script src="https://cdn.cookielaw.org/consent/a58df52b-2812-4cc9-99c6-cf9bcfe5af8b/OtAutoBlock.js" type="text/javascript"></script>\n<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="a58df52b-2812-4cc9-99c6-cf9bcfe5af8b"></script>\n<script src="https://www.rte.ie/djstatic/dotie/privacy/cookie-functions.js?v=20221110v54586"></script>\n<script type="text/javascript">\n    var optanonCallbacks = [\n        __eraseIllegalCookies\n    ];\n    function OptanonWrapper() {\n        for (var i = 0; i < optanonCallbacks.length; i++) {\n            optanonCallbacks[i].call();\n        }\n    }\n</script>\n\n<meta charset="utf-8" />\n<meta http-equiv="x-ua-compatible" content="ie=edge" />\n<meta name="viewport" content="width=device-width, height=device-height, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n<title>RTÉ Ireland&#x27;s National Te
# ...

# %%
weather = requests.get('https://api.oceandrivers.com/static/resources.json')

# %%
weather.text
# Out:
# '{\n  "apiVersion": "1.0",\n  "swaggerVersion": "1.2",\n  "apis": [\n    {\n      "path": "/../../api/ODWeather",\n      "description": "ODWeather API service"\n    }\n  ],\n   "info": {\n    "title": "ODWeather API Documentation",\n    "description": "This is the api to access the ODWeather API information",\n    "contact": "matiasbonet@oceandrivers.com"\n  }\n}\n'

# %%
weather = weather.json()

# %%
weather.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-f3075ee8adeb> in <module>
# ----> 1 weather.text
#
# AttributeError: 'dict' object has no attribute 'text'

# %%
pd.DataFrame(nct)
# Out:
#                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 5 columns]

# %% [markdown]
# Sorting a dataframe can be sorted by the value of any of the columns.  For example i have sorted this by Test Centre and again by Year.  I have also sorted by two columns and they are Statistic and Test Centre

# %%
nct
# Out:
#                              Year       Test Centre    UNIT     VALUE
# Statistic
# Pass: Initial Test           2006  All test results  Number  359283.0
# Pass: Initial Test           2006        Abbeyfeale  Number    4762.0
# Pass: Initial Test           2006            Arklow  Number    5227.0
# Pass: Initial Test           2006           Athlone  Number    5496.0
# Pass: Initial Test           2006           Ballina  Number    3812.0
# ...                           ...               ...     ...       ...
# Total Number of Cars Tested  2020            Tralee  Number   17177.0
# Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# Total Number of Cars Tested  2020         Waterford  Number   27184.0
# Total Number of Cars Tested  2020          Westport  Number   14355.0
# Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 4 columns]

# %%
nct['Test Centre']
# Out:
# 0       All test results
# 1             Abbeyfeale
# 2                 Arklow
# 3                Athlone
# 4                Ballina
#               ...
# 4111              Tralee
# 4112           Tullamore
# 4113           Waterford
# 4114            Westport
# 4115             Youghal
# Name: Test Centre, Length: 4116, dtype: object

# %%
nct['Year']
# Out:
# 0       2006
# 1       2006
# 2       2006
# 3       2006
# 4       2006
#         ...
# 4111    2020
# 4112    2020
# 4113    2020
# 4114    2020
# 4115    2020
# Name: Year, Length: 4116, dtype: int64

# %%
list_of_columns = ['Statistic','Test Centre']

# %%
nct[list_of_columns]
# Out:
#                         Statistic       Test Centre
# 0              Pass: Initial Test  All test results
# 1              Pass: Initial Test        Abbeyfeale
# 2              Pass: Initial Test            Arklow
# 3              Pass: Initial Test           Athlone
# 4              Pass: Initial Test           Ballina
# ...                           ...               ...
# 4111  Total Number of Cars Tested            Tralee
# 4112  Total Number of Cars Tested         Tullamore
# 4113  Total Number of Cars Tested         Waterford
# 4114  Total Number of Cars Tested          Westport
# 4115  Total Number of Cars Tested           Youghal
#
# [4116 rows x 2 columns]

# %% [markdown]
# Slicing, I have sliced the rows 0 to 5 and i have also pulled out the year.  The first 5 rows have been returned

# %%
nct[0:5]['Year']
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: Year, dtype: int64

# %%
Indexing by a number-In this example i have sliced by numbers 2:20, so it is bringing back the first 20 rows

# %%
nct.iloc[2:20]
# Out:
#              Statistic  Year         Test Centre    UNIT    VALUE
# 2   Pass: Initial Test  2006              Arklow  Number   5227.0
# 3   Pass: Initial Test  2006             Athlone  Number   5496.0
# 4   Pass: Initial Test  2006             Ballina  Number   3812.0
# 5   Pass: Initial Test  2006         Ballinasloe  Number      NaN
# 6   Pass: Initial Test  2006               Cahir  Number   7647.0
# 7   Pass: Initial Test  2006         Cahirciveen  Number    926.0
# 8   Pass: Initial Test  2006              Carlow  Number   6929.0
# 9   Pass: Initial Test  2006          Carndonagh  Number      NaN
# 10  Pass: Initial Test  2006  Carrick-on-Shannon  Number   4118.0
# 11  Pass: Initial Test  2006           Castlerea  Number   3456.0
# 12  Pass: Initial Test  2006               Cavan  Number   3767.0
# 13  Pass: Initial Test  2006         Charleville  Number   4307.0
# 14  Pass: Initial Test  2006             Clifden  Number    963.0
# ...

# %%
Indexing by a word, in this example,i set the Test Centre as the row index and the Test Centre is not a column anymore.  I used the iloc method to retrieve daata for the test centre Derrybeg

# %%
nct_ind = nct.set_index('Test Centre')

# %%
nct_ind.loc['Derrybeg']
# Out:
#                                Statistic  Year    UNIT   VALUE
# Test Centre
# Derrybeg              Pass: Initial Test  2006  Number  1478.0
# Derrybeg              Pass: Initial Test  2007  Number  1370.0
# Derrybeg              Pass: Initial Test  2008  Number  1506.0
# Derrybeg              Pass: Initial Test  2009  Number  1710.0
# Derrybeg              Pass: Initial Test  2010  Number  1825.0
# ...                                  ...   ...     ...     ...
# Derrybeg     Total Number of Cars Tested  2016  Number  5792.0
# Derrybeg     Total Number of Cars Tested  2017  Number  5413.0
# Derrybeg     Total Number of Cars Tested  2018  Number  5272.0
# Derrybeg     Total Number of Cars Tested  2019  Number  5452.0
# Derrybeg     Total Number of Cars Tested  2020  Number  4690.0
#
# [84 rows x 4 columns]

# %%
Filtering-I have pulled back Statistic Column,and the information returned is just the Statistic column

# %%
nct['Statistic']
# Out:
# 0                Pass: Initial Test
# 1                Pass: Initial Test
# 2                Pass: Initial Test
# 3                Pass: Initial Test
# 4                Pass: Initial Test
#                    ...
# 4111    Total Number of Cars Tested
# 4112    Total Number of Cars Tested
# 4113    Total Number of Cars Tested
# 4114    Total Number of Cars Tested
# 4115    Total Number of Cars Tested
# Name: Statistic, Length: 4116, dtype: object

# %%
nct
# Out:
#                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 5 columns]

# %% [markdown]
# **Grouping** is combining data based on the values in the Year column

# %%
nct.groupby(['VALUE']).mean()
# Out:
#              Year
# VALUE
# 58.0       2008.0
# 60.0       2019.0
# 63.0       2007.0
# 75.0       2006.0
# 78.0       2006.0
# ...           ...
# 1380111.0  2016.0
# 1390586.0  2019.0
# 1414820.0  2015.0
# 1465710.0  2016.0
# 1492180.0  2015.0
#
# [3500 rows x 1 columns]

# %%
nct.groupby(['Statistic','Test Centre']).mean().reset_index()
# Out:
#                              Statistic       Test Centre    Year         VALUE
# 0    Fail or No Show Following Re-Test        Abbeyfeale  2013.0    642.900000
# 1    Fail or No Show Following Re-Test  All test results  2013.0  62144.900000
# 2    Fail or No Show Following Re-Test            Arklow  2013.0   1308.700000
# 3    Fail or No Show Following Re-Test           Athlone  2013.0    853.700000
# 4    Fail or No Show Following Re-Test           Ballina  2013.0    593.900000
# ..                                 ...               ...     ...           ...
# 289             Total Number of Passes            Tralee  2013.0  17374.428571
# 290             Total Number of Passes         Tullamore  2013.0  14850.071429
# 291             Total Number of Passes         Waterford  2013.0  28756.071429
# 292             Total Number of Passes          Westport  2013.0  16364.000000
# 293             Total Number of Passes           Youghal  2013.0  11798.071429
#
# [294 rows x 4 columns]

# %% [markdown]
# **MISSING VALUES**, i have used the na function.  The value column has returned with 373 rows of missing values. I also used the dropna function and the data the table then returned 3743 rows so over 350 records were dropped.  The dropna(axis =1) returned 4 columns insstead of 5 as per the shape function.  The dropna (axis=0) returned 3743 rows of information and the shape function confirmed that i lost 373 rows

# %%
nct.isna().sum()
# Out:
# Statistic        0
# Year             0
# Test Centre      0
# UNIT             0
# VALUE          373
# dtype: int64

# %%
nct.dropna(axis=1).shape
# Out:
# (4116, 4)

# %%
nct.dropna(axis=0).shape
# Out:
# (3743, 5)

# %% [markdown]
# *DROP DUPLICATES-I used the drop duplicates function to drop any duplicate information but there is none in this datasest

# %%
nct.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# ...

# %%
nct.fillna('none')
# Out:
#                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 5 columns]

# %%
nct.fillna({'VALUE':'0000'})
# Out:
#                         Statistic  Year       Test Centre    UNIT     VALUE
# 0              Pass: Initial Test  2006  All test results  Number  359283.0
# 1              Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2              Pass: Initial Test  2006            Arklow  Number    5227.0
# 3              Pass: Initial Test  2006           Athlone  Number    5496.0
# 4              Pass: Initial Test  2006           Ballina  Number    3812.0
# ...                           ...   ...               ...     ...       ...
# 4111  Total Number of Cars Tested  2020            Tralee  Number   17177.0
# 4112  Total Number of Cars Tested  2020         Tullamore  Number   14980.0
# 4113  Total Number of Cars Tested  2020         Waterford  Number   27184.0
# 4114  Total Number of Cars Tested  2020          Westport  Number   14355.0
# 4115  Total Number of Cars Tested  2020           Youghal  Number   11524.0
#
# [4116 rows x 5 columns]

# %%
import requests

# %%
get.requests{'http://google.com'}
# Out:
#   File "<ipython-input-9-2453d405d541>", line 1
#     get.requests{'http://google.com'}
#                 ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
nct= pd.read_csv('nct.csv')

# %%
nct.dtypes
# Out:
# Statistic       object
# Year             int64
# Test Centre     object
# UNIT            object
# VALUE          float64
# dtype: object

# %%
nct.head()
# Out:
#             Statistic  Year       Test Centre    UNIT     VALUE
# 0  Pass: Initial Test  2006  All test results  Number  359283.0
# 1  Pass: Initial Test  2006        Abbeyfeale  Number    4762.0
# 2  Pass: Initial Test  2006            Arklow  Number    5227.0
# 3  Pass: Initial Test  2006           Athlone  Number    5496.0
# 4  Pass: Initial Test  2006           Ballina  Number    3812.0

# %%
plt.scatter(nct['Year'], nct['VALUE'],s=2)
plt.title('National Car Test')
# Out:
# Text(0.5, 1.0, 'National Car Test')

# %%
plt.show()

# %%
sns.scatterplot(data=nct, x='VALUE', y='Statistic', hue = 'Year')

# %%
sns.barplot(data=nct, y='Statistic', x='VALUE',)
