# %% [markdown]
# <a href="https://colab.research.google.com/github/hartyl1/UCDPA_harty/blob/main/Copy_of_Copy_of_Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Data-For this project i am using a dataset called Driving_licenses.  The data is taken from the cso.ie and provides statistis of Full and Learner Permit Driving Licenses between 2009 and 2020

# %%
import pandas as pd

# %%
Driving_Licenses=pd.read_csv('Driving_Licenses.csv')

# %%
Driving_Licenses
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %% [markdown]
# Retrieve data using API's

# %%
import requests

# %%
import pandas as pd

# %%
palma=requests.get('https://api.oceandrivers.com:443/v1.0/getWeatherDisplay/areopuertopalma/?period=latestdata')

# %%
palma.text
# Out:
# '{"TWS_GUST_MAX": {"VALUE": "22.0"}, "TWD": 80.0, "HUMIDEX": 13.3, "TWS": 1.8, "LOCALTIME": 2, "HUMIDITY_IN": 100.0, "WINDCHILL": 12.3, "TEMP_IN": 45.0, "ICON_NOW": "1", "ICON_FOR": "1", "TEMPERATURE": 12.3, "TWS_GUST": 0.9, "RAIN": 0.0, "PRESSURE": 1014.0, "LONGITUDE": 2.733, "ACTIVE": "OFF", "PRESSURE_TR": 0.4, "RAIN_MONTH": 14.7, "RAIN_DAY": 3.0, "HUMIDITY": 83.0, "TIME_STRING": "19-11-2022 18:49:16", "TIME": 1668876556000, "LATITUDE": 39.5, "WEATHER_DES": "Dry/Night_time"}'

# %%
palma=palma.json()

# %%
palma=requests.get('https://api.oceandrivers.com:443/v1.0/getWeatherDisplay/areopuertopalma/?period=latestdata')
palma=palma.json()
palma['palma_position']['palma_latitude']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-19d06017d88b> in <module>
#       1 palma=requests.get('https://api.oceandrivers.com:443/v1.0/getWeatherDisplay/areopuertopalma/?period=latestdata')
#       2 palma=palma.json()
# ----> 3 palma['palma_position']['palma_latitude']
#
# KeyError: 'palma_position'

# %% [markdown]
# Preparation

# %%
pd.DataFrame(Driving_Licenses)
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %%
Driving_Licenses.head()
# Out:
#          Statistic Label  Year       Age Group         Sex    VALUE
# 0  Full Driving Licences  2009        All ages  Both sexes  2362292
# 1  Full Driving Licences  2009        All ages        Male  1294008
# 2  Full Driving Licences  2009        All ages      Female  1068284
# 3  Full Driving Licences  2009  Under 17 years  Both sexes        3
# 4  Full Driving Licences  2009  Under 17 years        Male        1

# %%
Driving_Licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Statistic Label  792 non-null    object
#  1   Year             792 non-null    int64
#  2   Age Group        792 non-null    object
#  3   Sex              792 non-null    object
#  4   VALUE            792 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 31.1+ KB

# %%
Driving_Licenses.columns
# Out:
# Index(['Statistic Label', 'Year', 'Age Group', 'Sex', 'VALUE'], dtype='object')

# %%
Driving_Licenses.index
# Out:
# RangeIndex(start=0, stop=792, step=1)

# %%
Driving_Licenses['Year']
# Out:
# 0      2009
# 1      2009
# 2      2009
# 3      2009
# 4      2009
#        ...
# 787    2020
# 788    2020
# 789    2020
# 790    2020
# 791    2020
# Name: Year, Length: 792, dtype: int64

# %%
list_of_columns = ['Statistic Label', 'Sex']

# %%
Driving_Licenses
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %%
Driving_Licenses['Age Group']
# Out:
# 0               All ages
# 1               All ages
# 2               All ages
# 3         Under 17 years
# 4         Under 17 years
#              ...
# 787        70 - 79 years
# 788        70 - 79 years
# 789    80 years and over
# 790    80 years and over
# 791    80 years and over
# Name: Age Group, Length: 792, dtype: object

# %%
Driving_Licenses['Sex']
# Out:
# 0      Both sexes
# 1            Male
# 2          Female
# 3      Both sexes
# 4            Male
#           ...
# 787          Male
# 788        Female
# 789    Both sexes
# 790          Male
# 791        Female
# Name: Sex, Length: 792, dtype: object

# %%
list_of_columns = ['Age Group','Value']

# %% [markdown]
# Slicing, I have sliced the rows 0 to 5 and i have also pulled out the year.  The first 5 rows have been returned

# %%
Driving_Licenses[0:5]['Year']
# Out:
# 0    2009
# 1    2009
# 2    2009
# 3    2009
# 4    2009
# Name: Year, dtype: int64

# %%
Driving_Licenses.iloc[2:20]
# Out:
#           Statistic Label  Year       Age Group         Sex    VALUE
# 2   Full Driving Licences  2009        All ages      Female  1068284
# 3   Full Driving Licences  2009  Under 17 years  Both sexes        3
# 4   Full Driving Licences  2009  Under 17 years        Male        1
# 5   Full Driving Licences  2009  Under 17 years      Female        2
# 6   Full Driving Licences  2009   17 - 20 years  Both sexes    46258
# 7   Full Driving Licences  2009   17 - 20 years        Male    28631
# 8   Full Driving Licences  2009   17 - 20 years      Female    17627
# 9   Full Driving Licences  2009   21 - 24 years  Both sexes   132124
# 10  Full Driving Licences  2009   21 - 24 years        Male    71179
# 11  Full Driving Licences  2009   21 - 24 years      Female    60945
# 12  Full Driving Licences  2009   25 - 29 years  Both sexes   249341
# 13  Full Driving Licences  2009   25 - 29 years        Male   127963
# 14  Full Driving Licences  2009   25 - 29 years      Female   121378
# ...

# %%
Driving_Licenses_ind = Driving_Licenses.set_index('Sex')

# %%
Driving_Licenses_ind.loc['Both sexes']
# Out:
#                             Statistic Label  Year          Age Group    VALUE
# Sex
# Both sexes            Full Driving Licences  2009           All ages  2362292
# Both sexes            Full Driving Licences  2009     Under 17 years        3
# Both sexes            Full Driving Licences  2009      17 - 20 years    46258
# Both sexes            Full Driving Licences  2009      21 - 24 years   132124
# Both sexes            Full Driving Licences  2009      25 - 29 years   249341
# ...                                     ...   ...                ...      ...
# Both sexes  Learner Permit Driving Licences  2020      40 - 49 years    27728
# Both sexes  Learner Permit Driving Licences  2020      50 - 59 years    11485
# Both sexes  Learner Permit Driving Licences  2020      60 - 69 years     4397
# Both sexes  Learner Permit Driving Licences  2020      70 - 79 years     1496
# Both sexes  Learner Permit Driving Licences  2020  80 years and over      241
#
# [264 rows x 4 columns]

# %%
Filtering-I have pulled back Statistic Column,and the information returned is just the Statistic column
# Out:
#   File "<ipython-input-97-29389430af49>", line 1
#     Filtering-I have pulled back Statistic Column,and the information returned is just the Statistic column
#                    ^
# SyntaxError: invalid syntax

# %%
Driving_Licenses['Statistic Label']
# Out:
# 0                Full Driving Licences
# 1                Full Driving Licences
# 2                Full Driving Licences
# 3                Full Driving Licences
# 4                Full Driving Licences
#                     ...
# 787    Learner Permit Driving Licences
# 788    Learner Permit Driving Licences
# 789    Learner Permit Driving Licences
# 790    Learner Permit Driving Licences
# 791    Learner Permit Driving Licences
# Name: Statistic Label, Length: 792, dtype: object

# %%
Driving_Licenses
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %% [markdown]
# **Grouping** is combining data based on the values in the Year column

# %%
Driving_Licenses.groupby(['VALUE']).mean()
# Out:
#            Year
# VALUE
# 0        2015.0
# 1        2009.0
# 2        2009.0
# 3        2009.0
# 59       2018.0
# ...         ...
# 2570871  2016.0
# 2620014  2017.0
# 2667128  2018.0
# 2814887  2019.0
# 2834070  2020.0
#
# [752 rows x 1 columns]

# %%
Driving_Licenses.groupby(['Statistic Label','Sex']).mean().reset_index()
# Out:
#                    Statistic Label         Sex    Year          VALUE
# 0            Full Driving Licences  Both sexes  2014.5  461610.696970
# 1            Full Driving Licences      Female  2014.5  213883.757576
# 2            Full Driving Licences        Male  2014.5  247726.787879
# 3  Learner Permit Driving Licences  Both sexes  2014.5   45792.530303
# 4  Learner Permit Driving Licences      Female  2014.5   23256.696970
# 5  Learner Permit Driving Licences        Male  2014.5   22535.833333

# %% [markdown]
# **MISSING VALUES**, i have used the na function.  The value column has returned with 373 rows of missing values. I also used the dropna function and the data the table then returned 3743 rows so over 350 records were dropped.  The dropna(axis =1) returned 4 columns insstead of 5 as per the shape function.  The dropna (axis=0) returned 3743 rows of information and the shape function confirmed that i lost 373 rows

# %%
Driving_Licenses.isna().sum()
# Out:
# Statistic Label    0
# Year               0
# Age Group          0
# Sex                0
# VALUE              0
# dtype: int64

# %%
Driving_Licenses.dropna(axis=1).shape
# Out:
# (792, 5)

# %% [markdown]
# *DROP DUPLICATES-I used the drop duplicates function to drop any duplicate information but there is none in this datasest

# %%
Driving_Licenses.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# ...

# %%
Driving_Licenses.fillna('none')
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %%
Driving_Licenses.fillna({'VALUE':'0000'})
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %% [markdown]
# Merge DataFrames

# %%
Driving_Licenses=pd.read_csv('Driving_Licenses.csv')

# %%
nct=pd.read_csv('nct.csv')

# %%
Driving_Licenses.merge(nct,how='outer')
# Out:
#                   Statistic Label  Year       Age Group         Sex  \
# 0           Full Driving Licences  2009        All ages  Both sexes
# 1           Full Driving Licences  2009        All ages        Male
# 2           Full Driving Licences  2009        All ages      Female
# 3           Full Driving Licences  2009  Under 17 years  Both sexes
# 4           Full Driving Licences  2009  Under 17 years        Male
# ...                           ...   ...             ...         ...
# 4903  Total Number of Cars Tested  2020             NaN         NaN
# 4904  Total Number of Cars Tested  2020             NaN         NaN
# 4905  Total Number of Cars Tested  2020             NaN         NaN
# 4906  Total Number of Cars Tested  2020             NaN         NaN
# 4907  Total Number of Cars Tested  2020             NaN         NaN
#
#           VALUE Test Centre    UNIT
# 0     2362292.0         NaN     NaN
# 1     1294008.0         NaN     NaN
# 2     1068284.0         NaN     NaN
# ...

# %%
employee=pd.DataFrame({'employee': ['Brian', 'James', 'Brid', 'Lorraine'],
                    'group': ['Sales', 'Claims', 'Customer_care', 'HR']})
start=pd.DataFrame({'employee': ['James', 'Brian', 'Brid', 'Lorraine'],
                    'start_date': [2014, 2020, 2019, 2017]})

# %%
employee.merge(start)
# Out:
#    employee          group  start_date
# 0     Brian          Sales        2020
# 1     James         Claims        2014
# 2      Brid  Customer_care        2019
# 3  Lorraine             HR        2017

# %%
import requests

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
Driving_Licenses
# Out:
#                      Statistic Label  Year          Age Group         Sex  \
# 0              Full Driving Licences  2009           All ages  Both sexes
# 1              Full Driving Licences  2009           All ages        Male
# 2              Full Driving Licences  2009           All ages      Female
# 3              Full Driving Licences  2009     Under 17 years  Both sexes
# 4              Full Driving Licences  2009     Under 17 years        Male
# ..                               ...   ...                ...         ...
# 787  Learner Permit Driving Licences  2020      70 - 79 years        Male
# 788  Learner Permit Driving Licences  2020      70 - 79 years      Female
# 789  Learner Permit Driving Licences  2020  80 years and over  Both sexes
# 790  Learner Permit Driving Licences  2020  80 years and over        Male
# 791  Learner Permit Driving Licences  2020  80 years and over      Female
#
#        VALUE
# 0    2362292
# 1    1294008
# 2    1068284
# 3          3
# ...

# %%
plt.scatter(Driving_Licenses['VALUE'],Driving_Licenses['Age Group'],s=2)
plt.title('Current Full & Learner Permit Driving Licenses')
# Out:
# Text(0.5, 1.0, 'Current Full & Learner Permit Driving Licenses')

# %%
plt.show()

# %%
sns.scatterplot(data=Driving_Licenses, x='Statistic Label', y='Sex', hue = 'Sex')

# %%
sns.barplot(data=Driving_Licenses, y='Statistic Label', x='VALUE',)
